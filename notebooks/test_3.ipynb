# %%
# %load_ext autoreload
# %autoreload 2
import cascadesimulator

# %%
cascadesimulator.main()
# Out:
# CascadeSimulator is ready to use!
# Hello from CascadeSimuulator in main.cpp!22

# %%
cascadesimulator.cascade_generator_cpp.CascadeGenerator
# Out:
# cascadesimulator.cascade_generator_cpp.CascadeGenerator
